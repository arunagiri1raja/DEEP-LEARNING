# %% [markdown]
# # **PART D: DEEP LEARNING EXPERIMENT MANAGEMENT**

# %% [markdown]
# **Mount Google Drive**

# %%
# Mount Google Drive

import os
from google.colab import drive

drive.mount('/content/drive')

print("NAME: AKHIL C\nROLL NO: 24BAD007")
# Out:
# Mounted at /content/drive
# NAME: AKHIL C
# ROLL NO: 24BAD007

# %% [markdown]
# **Import Required Libraries**

# %%
# Import required libraries

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist

# %% [markdown]
# **Load and Prepare the DatasetLoad and Prepare the Dataset**

# %%
# Load and prepare the dataset

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784) / 255.0
X_test = X_test.reshape(10000, 784) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# **Build the Model**

# %%
# Build the model

model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# **Compile the Model**

# %%
# Compile the model

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **Train the Model**

# %%
# Train the model

history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9291 - loss: 0.2424 - val_accuracy: 0.9644 - val_loss: 0.1267
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9690 - loss: 0.1022 - val_accuracy: 0.9708 - val_loss: 0.0935
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9781 - loss: 0.0712 - val_accuracy: 0.9706 - val_loss: 0.0934
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9825 - loss: 0.0552 - val_accuracy: 0.9773 - val_loss: 0.0805
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9855 - loss: 0.0443 - val_accuracy: 0.9770 - val_loss: 0.0812

# %% [markdown]
# **Save the Model**

# %%
# Save the model

model.save('/content/drive/MyDrive/model.keras')

print("Model saved successfully!")
# Out:
# Model saved successfully!
